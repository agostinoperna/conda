# %%
import pandas as pd
# %matplotlib inline

# %%
df=pd.read_csv("https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-regioni/dpc-covid19-ita-regioni-latest.csv")

# %%
df
# Out:
#                    data stato  codice_regione  denominazione_regione  \
# 0   2022-02-22T17:00:00   ITA              13                Abruzzo
# 1   2022-02-22T17:00:00   ITA              17             Basilicata
# 2   2022-02-22T17:00:00   ITA              18               Calabria
# 3   2022-02-22T17:00:00   ITA              15               Campania
# 4   2022-02-22T17:00:00   ITA               8         Emilia-Romagna
# 5   2022-02-22T17:00:00   ITA               6  Friuli Venezia Giulia
# 6   2022-02-22T17:00:00   ITA              12                  Lazio
# 7   2022-02-22T17:00:00   ITA               7                Liguria
# 8   2022-02-22T17:00:00   ITA               3              Lombardia
# 9   2022-02-22T17:00:00   ITA              11                 Marche
# 10  2022-02-22T17:00:00   ITA              14                 Molise
# 11  2022-02-22T17:00:00   ITA              21           P.A. Bolzano
# 12  2022-02-22T17:00:00   ITA              22            P.A. Trento
# ...

# %%
df.sum()
# Out:
# data                                      2022-02-22T17:00:002022-02-22T17:00:002022-02-...
# stato                                     ITAITAITAITAITAITAITAITAITAITAITAITAITAITAITAI...
# codice_regione                                                                          249
# denominazione_regione                     AbruzzoBasilicataCalabriaCampaniaEmilia-Romagn...
# lat                                                                                 903.972
# long                                                                                256.745
# ricoverati_con_sintomi                                                                13076
# terapia_intensiva                                                                       896
# totale_ospedalizzati                                                                  13972
# isolamento_domiciliare                                                              1277821
# ...

# %%
df[["denominazione_regione","ricoverati_con_sintomi"]].sort_values(by="ricoverati_con_sintomi",ascending=False)
# Out:
#     denominazione_regione  ricoverati_con_sintomi
# 4          Emilia-Romagna                    1704
# 6                   Lazio                    1665
# 8               Lombardia                    1272
# 13               Piemonte                    1175
# 16                Sicilia                    1169
# 3                Campania                     982
# 17                Toscana                     967
# 20                 Veneto                     771
# 14                 Puglia                     727
# 7                 Liguria                     458
# 0                 Abruzzo                     430
# 15               Sardegna                     364
# 2                Calabria                     344
# 5   Friuli Venezia Giulia                     301
# 9                  Marche                     263
# 18                 Umbria                     164
# 1              Basilicata                     109
# 11           P.A. Bolzano                      81
# ...

# %%
df_plot=df[["denominazione_regione","ricoverati_con_sintomi"]]

# %%
df_plot.plot(kind="bar",)
# Out:
# <AxesSubplot:>

# %%
df_plot.plot(kind="bar",x="denominazione_regione", figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='denominazione_regione'>

# %%
df_plot=df[["denominazione_regione","ricoverati_con_sintomi"]].sort_values(by="ricoverati_con_sintomi",ascending=False)

# %%
df_plot.plot(kind="bar",x="denominazione_regione", figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='denominazione_regione'>

# %%
df2=pd.read_csv("https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-andamento-nazionale/dpc-covid19-ita-andamento-nazionale.csv")

# %%
df2
# Out:
#                     data stato  ricoverati_con_sintomi  terapia_intensiva  \
# 0    2020-02-24T18:00:00   ITA                     101                 26
# 1    2020-02-25T18:00:00   ITA                     114                 35
# 2    2020-02-26T18:00:00   ITA                     128                 36
# 3    2020-02-27T18:00:00   ITA                     248                 56
# 4    2020-02-28T18:00:00   ITA                     345                 64
# ..                   ...   ...                     ...                ...
# 725  2022-02-18T17:00:00   ITA                   13948                987
# 726  2022-02-19T17:00:00   ITA                   13387                953
# 727  2022-02-20T17:00:00   ITA                   13284                934
# 728  2022-02-21T17:00:00   ITA                   13375                928
# 729  2022-02-22T17:00:00   ITA                   13076                896
#
#      totale_ospedalizzati  isolamento_domiciliare  totale_positivi  \
# ...

# %%
df2_plot=df2[["data","totale_casi"]]

# %%
df2_plot.plot(x="data",y="totale_casi", figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='data'>

# %%
df3_plot=df2[["data","deceduti"]]

# %%
df3_plot.plot(x="data",y="deceduti", figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='data'>

# %%
df2[["totale_positivi","dimessi_guariti"]]
# Out:
#      totale_positivi  dimessi_guariti
# 0                221                1
# 1                311                1
# 2                385                3
# 3                588               45
# 4                821               46
# ..               ...              ...
# 725          1404122         10820380
# 726          1369778         10905147
# 727          1348347         10968639
# 728          1321971         11019298
# 729          1291793         11109291
#
# [730 rows x 2 columns]

# %%
df2[["data","totale_positivi","dimessi_guariti","deceduti"]].plot(x="data",figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='data'>

# %%
df2[["data","dimessi_guariti","deceduti"]].plot(x="data",figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='data'>
